# %% [markdown]
# # Catanatron Introduction
# This shows example usage of Catanatron. First, you can implement your own bot strategy and pit against some benchmark bots.

# %%
import random

from catanatron.game import Game
from catanatron.models.player import Player, RandomPlayer, Color
from catanatron.players.weighted_random import WeightedRandomPlayer

class MyPlayer(Player):
    def decide(self, game, playable_actions):
        """Should return one of the playable_actions.

        Args:
            game (Game): complete game state. read-only.
            playable_actions (Iterable[Action]): options to choose from
        Return:
            action (Action): Chosen element of playable_actions
        """
        # ===== YOUR CODE HERE =====
        # As an example we simply choose a valid action at random:
        return random.choice(playable_actions)
        # ===== END YOUR CODE =====

# Play a simple 4v4 game. Edit MyPlayer with your logic!
players = [
    MyPlayer(Color.RED),
    WeightedRandomPlayer(Color.BLUE),
    RandomPlayer(Color.WHITE),
    RandomPlayer(Color.ORANGE),
]
game = Game(players)
print(game.play())  # returns winning color
# Out:
# Color.BLUE

# %% [markdown]
# You can also simulate thousands of games to get more statistically significant results:

# %%
from pprint import pprint
from catanatron_experimental.play import play_batch

wins, results_by_player, games = play_batch(10, players)

pprint(wins)
pprint(results_by_player)
# Out:
# 2022-01-09 13:43:02.381509: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-09 13:43:02.381540: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-01-09 13:43:03,520 DEBUG Playing game 1 / 10. Seating: [WeightedRandomPlayer:BLUE, MyPlayer:RED, RandomPlayer:WHITE, RandomPlayer:ORANGE]
# 2022-01-09 13:43:03,575 DEBUG {'MyPlayer:RED': 3, 'WeightedRandomPlayer:BLUE': 2, 'RandomPlayer:WHITE': 7, 'RandomPlayer:ORANGE': 10} (0.0545 secs) [Color.ORANGE:173(537)]
# 2022-01-09 13:43:03,578 DEBUG Playing game 2 / 10. Seating: [RandomPlayer:WHITE, MyPlayer:RED, RandomPlayer:ORANGE, WeightedRandomPlayer:BLUE]
# 2022-01-09 13:43:03,637 DEBUG {'MyPlayer:RED': 2, 'WeightedRandomPlayer:BLUE': 5, 'RandomPlayer:WHITE': 10, 'RandomPlayer:ORANGE': 2} (0.0583 secs) [Color.WHITE:178(533)]
# 2022-01-09 13:43:03,640 DEBUG Playing game 3 / 10. Seating: [RandomPlayer:ORANGE, RandomPlayer:WHITE, WeightedRandomPlayer:BLUE, MyPlayer:RED]
# 2022-01-09 13:43:03,760 DEBUG {'MyPlayer:RED': 4, 'WeightedRandomPlayer:BLUE': 10, 'RandomPlayer:WHITE': 8, 'RandomPlayer:ORANGE': 7} (0.119 secs) [Color.BLUE:380(1211)]
# 2022-01-09 13:43:03,763 DEBUG Playing game 4 / 10. Seating: [WeightedRandomPlayer:BLUE, MyPlayer:RED, RandomPlayer:ORANGE, RandomPlayer:WHITE]
# 2022-01-09 13:43:03,813 DEBUG {'MyPlayer:RED': 8, 'WeightedRandomPlayer:BLUE': 3, 'RandomPlayer:WHITE': 2, 'RandomPlayer:ORANGE': 10} (0.0491 secs) [Color.ORANGE:136(438)]
# 2022-01-09 13:43:03,817 DEBUG Playing game 5 / 10. Seating: [RandomPlayer:ORANGE, WeightedRandomPlayer:BLUE, MyPlayer:RED, RandomPlayer:WHITE]
# 2022-01-09 13:43:03,867 DEBUG {'MyPlayer:RED': 2, 'WeightedRandomPlayer:BLUE': 11, 'RandomPlayer:WHITE': 2, 'RandomPlayer:ORANGE': 2} (0.0491 secs) [Color.BLUE:143(433)]
# 2022-01-09 13:43:03,870 DEBUG Playing game 6 / 10. Seating: [WeightedRandomPlayer:BLUE, RandomPlayer:WHITE, RandomPlayer:ORANGE, MyPlayer:RED]
# 2022-01-09 13:43:03,938 DEBUG {'MyPlayer:RED': 5, 'WeightedRandomPlayer:BLUE': 2, 'RandomPlayer:WHITE': 2, 'RandomPlayer:ORANGE': 10} (0.0674 secs) [Color.ORANGE:232(683)]
# 2022-01-09 13:43:03,942 DEBUG Playing game 7 / 10. Seating: [RandomPlayer:WHITE, MyPlayer:RED, RandomPlayer:ORANGE, WeightedRandomPlayer:BLUE]
# 2022-01-09 13:43:04,053 DEBUG {'MyPlayer:RED': 6, 'WeightedRandomPlayer:BLUE': 9, 'RandomPlayer:WHITE': 10, 'RandomPlayer:ORANGE': 4} (0.11 secs) [Color.WHITE:338(1070)]
# 2022-01-09 13:43:04,055 DEBUG Playing game 8 / 10. Seating: [RandomPlayer:WHITE, MyPlayer:RED, RandomPlayer:ORANGE, WeightedRandomPlayer:BLUE]
# 2022-01-09 13:43:04,102 DEBUG {'MyPlayer:RED': 5, 'WeightedRandomPlayer:BLUE': 4, 'RandomPlayer:WHITE': 10, 'RandomPlayer:ORANGE': 2} (0.0465 secs) [Color.WHITE:162(495)]
# 2022-01-09 13:43:04,107 DEBUG Playing game 9 / 10. Seating: [MyPlayer:RED, RandomPlayer:WHITE, WeightedRandomPlayer:BLUE, RandomPlayer:ORANGE]
# 2022-01-09 13:43:04,194 DEBUG {'MyPlayer:RED': 7, 'WeightedRandomPlayer:BLUE': 2, 'RandomPlayer:WHITE': 2, 'RandomPlayer:ORANGE': 10} (0.0862 secs) [Color.ORANGE:329(899)]
# 2022-01-09 13:43:04,196 DEBUG Playing game 10 / 10. Seating: [MyPlayer:RED, RandomPlayer:ORANGE, WeightedRandomPlayer:BLUE, RandomPlayer:WHITE]
# 2022-01-09 13:43:04,275 DEBUG {'MyPlayer:RED': 9, 'WeightedRandomPlayer:BLUE': 10, 'RandomPlayer:WHITE': 2, 'RandomPlayer:ORANGE': 2} (0.0776 secs) [Color.BLUE:264(797)]
# 2022-01-09 13:43:04,276 INFO AVG Ticks: 709.6
# 2022-01-09 13:43:04,276 INFO AVG Turns: 233.5
# 2022-01-09 13:43:04,278 INFO AVG Duration: 0.072 secs
# 2022-01-09 13:43:04,279 INFO AVG VPS: MyPlayer:RED 5.1
# 2022-01-09 13:43:04,280 INFO AVG VPS: WeightedRandomPlayer:BLUE 5.8
# 2022-01-09 13:43:04,281 INFO AVG VPS: RandomPlayer:WHITE 5.5
# 2022-01-09 13:43:04,283 INFO AVG VPS: RandomPlayer:ORANGE 5.9
# 2022-01-09 13:43:04,284 INFO MyPlayer:RED               [0]
# 2022-01-09 13:43:04,284 INFO WeightedRandomPlayer:BLUE  [3]  ██████████████████████████████
# 2022-01-09 13:43:04,292 INFO RandomPlayer:WHITE         [3]  ██████████████████████████████
# 2022-01-09 13:43:04,293 INFO RandomPlayer:ORANGE        [4]  ████████████████████████████████████████
# {<Color.RED: 'RED'>: 0,
#  <Color.BLUE: 'BLUE'>: 3,
#  <Color.ORANGE: 'ORANGE'>: 4,
#  <Color.WHITE: 'WHITE'>: 3}
# {<Color.RED: 'RED'>: [3, 2, 4, 8, 2, 5, 6, 5, 7, 9],
#  <Color.BLUE: 'BLUE'>: [2, 5, 10, 3, 11, 2, 9, 4, 2, 10],
#  <Color.ORANGE: 'ORANGE'>: [10, 2, 7, 10, 2, 10, 4, 2, 10, 2],
#  <Color.WHITE: 'WHITE'>: [7, 10, 8, 2, 2, 2, 10, 10, 2, 2]}

# %% [markdown]
# You can inspect the game states in a variety of ways and compute statistics

# %%
from catanatron.json import GameEncoder
from catanatron_gym.features import create_sample_vector, create_sample
from catanatron_experimental.machine_learning.board_tensor_features import (
    create_board_tensor,
)

game = games[0]  # pick say the first one

# 1. Feature dictionary of last state before game ended from REDs perspective. 
#   See https://catanatron.readthedocs.io/en/latest/catanatron_gym.envs.html#catanatron_gym.envs.catanatron_env.CatanatronEnv.observation_space
#   for more information on this representation.
# record = create_sample(game, Color.RED)
# pprint(record)

# 2. Vector (similar to 1) of last state before game ended
# vector = create_sample_vector(game, Color.RED)
# print(vector)

# 3. Board Tensor representation, similar to the one described in https://arxiv.org/abs/2008.07079
# tensor = create_board_tensor(game, Color.RED)
# print(tensor)

# 4. Inspect Python catanatron.state.State class
# print(game.state)

# 5. JSON Representation (with full action history)
game_json = GameEncoder().default(game)
pprint(game_json)  # inspect a game state representation
# Out:
# {'actions': [Action(BLUE BUILD_SETTLEMENT 52),
#              Action(BLUE BUILD_ROAD (52, 53)),
#              Action(RED BUILD_SETTLEMENT 28),
#              Action(RED BUILD_ROAD (28, 29)),
#              Action(WHITE BUILD_SETTLEMENT 7),
#              Action(WHITE BUILD_ROAD (7, 8)),
#              Action(ORANGE BUILD_SETTLEMENT 49),
#              Action(ORANGE BUILD_ROAD (48, 49)),
#              Action(ORANGE BUILD_SETTLEMENT 12),
#              Action(ORANGE BUILD_ROAD (3, 12)),
#              Action(WHITE BUILD_SETTLEMENT 2),
#              Action(WHITE BUILD_ROAD (2, 9)),
#              Action(RED BUILD_SETTLEMENT 37),
#              Action(RED BUILD_ROAD (37, 38)),
#              Action(BLUE BUILD_SETTLEMENT 32),
#              Action(BLUE BUILD_ROAD (31, 32)),
#              Action(BLUE ROLL (3, 6)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (6, 2)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 2)),
#              Action(WHITE MOVE_ROBBER ((2, 0, -2), <Color.ORANGE: 'ORANGE'>, WHEAT)),
#              Action(WHITE BUILD_ROAD (2, 3)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (2, 1)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (1, 4)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (4, 4)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 6)),
#              Action(WHITE BUILD_ROAD (9, 10)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (3, 1)),
#              Action(ORANGE BUILD_ROAD (3, 4)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (3, 2)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (1, 2)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (6, 6)),
#              Action(WHITE BUILD_SETTLEMENT 10),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (1, 5)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (6, 5)),
#              Action(BLUE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, WHEAT)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (6, 2)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (1, 4)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, WOOD, WOOD, WHEAT)),
#              Action(WHITE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, WHEAT, ORE)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (6, 4)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (5, 3)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (6, 4)),
#              Action(RED MARITIME_TRADE (WOOD, WOOD, WOOD, None, WHEAT)),
#              Action(RED MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, WOOD)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (2, 4)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (5, 3)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (2, 6)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (4, 2)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (6, 5)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (1, 1)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (1, 4)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (4, 5)),
#              Action(RED MARITIME_TRADE (WOOD, WOOD, WOOD, None, ORE)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (3, 1)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, WOOD, WOOD, WHEAT)),
#              Action(WHITE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, WHEAT, WOOD)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (5, 3)),
#              Action(ORANGE BUILD_ROAD (46, 48)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (3, 3)),
#              Action(BLUE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, ORE)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (6, 3)),
#              Action(RED MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, BRICK)),
#              Action(RED BUILD_ROAD (36, 37)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (4, 3)),
#              Action(WHITE MOVE_ROBBER ((-1, 1, 0), None, None)),
#              Action(WHITE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, WHEAT, BRICK)),
#              Action(WHITE BUILD_ROAD (7, 24)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (2, 2)),
#              Action(ORANGE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, WOOD)),
#              Action(ORANGE BUILD_SETTLEMENT 46),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (3, 4)),
#              Action(BLUE MOVE_ROBBER ((0, -1, 1), <Color.WHITE: 'WHITE'>, SHEEP)),
#              Action(BLUE BUY_DEVELOPMENT_CARD DevelopmentCard.VICTORY_POINT),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (1, 4)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 5)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (5, 2)),
#              Action(ORANGE MOVE_ROBBER ((-2, 0, 2), <Color.RED: 'RED'>, ORE)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (1, 5)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (2, 2)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (2, 1)),
#              Action(WHITE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, SHEEP, WHEAT)),
#              Action(WHITE BUILD_ROAD (24, 25)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (2, 1)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (6, 5)),
#              Action(BLUE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, WHEAT)),
#              Action(BLUE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, BRICK)),
#              Action(BLUE BUILD_ROAD (23, 52)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (2, 5)),
#              Action(RED MOVE_ROBBER ((-1, -1, 2), <Color.ORANGE: 'ORANGE'>, ORE)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (4, 2)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (1, 5)),
#              Action(ORANGE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, BRICK)),
#              Action(ORANGE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, WHEAT)),
#              Action(ORANGE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, BRICK)),
#              Action(ORANGE MARITIME_TRADE (BRICK, BRICK, BRICK, None, WOOD)),
#              Action(ORANGE BUILD_ROAD (12, 13)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (2, 1)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (4, 5)),
#              Action(RED MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, ORE)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 5)),
#              Action(WHITE BUILD_SETTLEMENT 25),
#              Action(WHITE BUILD_ROAD (25, 26)),
#              Action(WHITE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, WHEAT, BRICK)),
#              Action(WHITE BUILD_ROAD (10, 11)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (4, 4)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (4, 2)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (2, 2)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 4)),
#              Action(WHITE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, WHEAT, BRICK)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (1, 6)),
#              Action(ORANGE MOVE_ROBBER ((2, -1, -1), <Color.WHITE: 'WHITE'>, ORE)),
#              Action(ORANGE BUILD_CITY 46),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (4, 1)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (4, 1)),
#              Action(RED MARITIME_TRADE (WOOD, WOOD, WOOD, None, WHEAT)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (1, 3)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, ORE)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (2, 5)),
#              Action(ORANGE MOVE_ROBBER ((0, -1, 1), <Color.WHITE: 'WHITE'>, SHEEP)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (3, 3)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (2, 5)),
#              Action(RED MOVE_ROBBER ((-1, 0, 1), <Color.ORANGE: 'ORANGE'>, SHEEP)),
#              Action(RED MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, WOOD)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (1, 2)),
#              Action(WHITE BUILD_ROAD (11, 12)),
#              Action(WHITE BUILD_ROAD (6, 7)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (3, 3)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (3, 2)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (3, 1)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (4, 3)),
#              Action(WHITE MOVE_ROBBER ((2, -1, -1), <Color.BLUE: 'BLUE'>, WOOD)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, ORE)),
#              Action(WHITE BUY_DEVELOPMENT_CARD DevelopmentCard.KNIGHT),
#              Action(WHITE PLAY_KNIGHT_CARD None),
#              Action(WHITE MOVE_ROBBER ((-2, 0, 2), <Color.RED: 'RED'>, WHEAT)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (4, 5)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (3, 2)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (2, 2)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (6, 2)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, WHEAT)),
#              Action(WHITE BUY_DEVELOPMENT_CARD DevelopmentCard.KNIGHT),
#              Action(WHITE PLAY_KNIGHT_CARD None),
#              Action(WHITE MOVE_ROBBER ((2, -2, 0), None, None)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (4, 4)),
#              Action(ORANGE BUY_DEVELOPMENT_CARD DevelopmentCard.KNIGHT),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (6, 5)),
#              Action(BLUE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, WOOD)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (5, 6)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (3, 4)),
#              Action(WHITE MOVE_ROBBER ((0, -2, 2), <Color.BLUE: 'BLUE'>, SHEEP)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (3, 3)),
#              Action(ORANGE MARITIME_TRADE (BRICK, BRICK, BRICK, None, WOOD)),
#              Action(ORANGE MARITIME_TRADE (BRICK, BRICK, BRICK, None, WOOD)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (1, 3)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (1, 2)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 3)),
#              Action(WHITE BUILD_ROAD (10, 29)),
#              Action(WHITE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, WHEAT, BRICK)),
#              Action(WHITE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, SHEEP, WOOD)),
#              Action(WHITE BUILD_ROAD (29, 30)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE PLAY_KNIGHT_CARD None),
#              Action(ORANGE MOVE_ROBBER ((1, -1, 0), None, None)),
#              Action(ORANGE ROLL (6, 5)),
#              Action(ORANGE BUILD_ROAD (45, 46)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (2, 6)),
#              Action(BLUE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, WOOD)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (5, 2)),
#              Action(RED MOVE_ROBBER ((-2, 2, 0), None, None)),
#              Action(RED BUY_DEVELOPMENT_CARD DevelopmentCard.VICTORY_POINT),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 3)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (1, 3)),
#              Action(ORANGE BUILD_ROAD (4, 5)),
#              Action(ORANGE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, WOOD)),
#              Action(ORANGE BUILD_ROAD (13, 14)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (3, 5)),
#              Action(BLUE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, WOOD)),
#              Action(BLUE MARITIME_TRADE (WOOD, WOOD, WOOD, None, WHEAT)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (4, 5)),
#              Action(RED MARITIME_TRADE (WOOD, WOOD, WOOD, None, ORE)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (2, 2)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (5, 2)),
#              Action(ORANGE MOVE_ROBBER ((-1, -1, 2), <Color.BLUE: 'BLUE'>, WHEAT)),
#              Action(ORANGE MARITIME_TRADE (ORE, ORE, ORE, None, WOOD)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (2, 4)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (5, 5)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (4, 4)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (6, 5)),
#              Action(ORANGE BUILD_ROAD (49, 50)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (6, 2)),
#              Action(BLUE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, BRICK)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (1, 1)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 5)),
#              Action(WHITE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, SHEEP, WOOD)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, SHEEP)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (1, 3)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (1, 3)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (5, 3)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 6)),
#              Action(WHITE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, SHEEP, BRICK)),
#              Action(WHITE BUILD_ROAD (1, 6)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (4, 3)),
#              Action(ORANGE MOVE_ROBBER ((-2, 2, 0), None, None)),
#              Action(ORANGE MARITIME_TRADE (BRICK, BRICK, BRICK, None, ORE)),
#              Action(ORANGE BUY_DEVELOPMENT_CARD DevelopmentCard.MONOPOLY),
#              Action(ORANGE PLAY_MONOPOLY Resource.WOOD),
#              Action(ORANGE BUILD_SETTLEMENT 4),
#              Action(ORANGE BUILD_ROAD (22, 49)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (5, 4)),
#              Action(BLUE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, WOOD)),
#              Action(BLUE BUILD_ROAD (11, 32)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (2, 1)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (1, 4)),
#              Action(WHITE BUILD_ROAD (6, 23)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (4, 6)),
#              Action(ORANGE BUY_DEVELOPMENT_CARD DevelopmentCard.KNIGHT),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (2, 3)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (3, 1)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (3, 5)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, WHEAT)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, ORE)),
#              Action(WHITE BUY_DEVELOPMENT_CARD DevelopmentCard.ROAD_BUILDING),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (6, 2)),
#              Action(ORANGE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, ORE)),
#              Action(ORANGE PLAY_KNIGHT_CARD None),
#              Action(ORANGE MOVE_ROBBER ((-2, 1, 1), <Color.RED: 'RED'>, ORE)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (3, 2)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (2, 6)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (2, 2)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, BRICK)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (2, 6)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (5, 2)),
#              Action(BLUE MOVE_ROBBER ((0, 1, -1), None, None)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (2, 6)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (1, 5)),
#              Action(WHITE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, WHEAT, SHEEP)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (6, 2)),
#              Action(ORANGE MARITIME_TRADE (ORE, ORE, ORE, None, WHEAT)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (1, 4)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (6, 5)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (2, 4)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, ORE)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (2, 1)),
#              Action(ORANGE MARITIME_TRADE (BRICK, BRICK, BRICK, None, ORE)),
#              Action(ORANGE BUY_DEVELOPMENT_CARD DevelopmentCard.KNIGHT),
#              Action(ORANGE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, BRICK)),
#              Action(ORANGE MARITIME_TRADE (BRICK, BRICK, BRICK, None, SHEEP)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (4, 5)),
#              Action(BLUE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, WOOD)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (4, 5)),
#              Action(RED MARITIME_TRADE (WOOD, WOOD, WOOD, None, BRICK)),
#              Action(RED BUILD_ROAD (35, 36)),
#              Action(RED MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, SHEEP)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 2)),
#              Action(WHITE MOVE_ROBBER ((1, 1, -2), <Color.ORANGE: 'ORANGE'>, SHEEP)),
#              Action(WHITE BUY_DEVELOPMENT_CARD DevelopmentCard.ROAD_BUILDING),
#              Action(WHITE END_TURN None),
#              Action(ORANGE PLAY_KNIGHT_CARD None),
#              Action(ORANGE MOVE_ROBBER ((1, -2, 1), <Color.WHITE: 'WHITE'>, SHEEP)),
#              Action(ORANGE ROLL (5, 2)),
#              Action(ORANGE MOVE_ROBBER ((2, 0, -2), <Color.BLUE: 'BLUE'>, WHEAT)),
#              Action(ORANGE MARITIME_TRADE (ORE, ORE, ORE, None, SHEEP)),
#              Action(ORANGE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, BRICK)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (1, 3)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (3, 4)),
#              Action(RED MOVE_ROBBER ((-1, -1, 2), <Color.ORANGE: 'ORANGE'>, BRICK)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 5)),
#              Action(WHITE BUILD_ROAD (8, 27)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (3, 3)),
#              Action(ORANGE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, BRICK)),
#              Action(ORANGE BUY_DEVELOPMENT_CARD DevelopmentCard.MONOPOLY),
#              Action(ORANGE PLAY_MONOPOLY Resource.WOOD),
#              Action(ORANGE BUILD_ROAD (50, 51)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (5, 4)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (6, 4)),
#              Action(RED BUILD_ROAD (14, 37)),
#              Action(RED BUY_DEVELOPMENT_CARD DevelopmentCard.KNIGHT),
#              Action(RED PLAY_KNIGHT_CARD None),
#              Action(RED MOVE_ROBBER ((0, -1, 1), <Color.WHITE: 'WHITE'>, BRICK)),
#              Action(RED BUILD_ROAD (38, 39)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (4, 2)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (6, 4)),
#              Action(ORANGE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, BRICK)),
#              Action(ORANGE BUILD_ROAD (4, 15)),
#              Action(ORANGE BUY_DEVELOPMENT_CARD DevelopmentCard.KNIGHT),
#              Action(ORANGE PLAY_KNIGHT_CARD None),
#              Action(ORANGE MOVE_ROBBER ((-1, 0, 1), None, None)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (1, 4)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (1, 1)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 5)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, BRICK)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, SHEEP)),
#              Action(WHITE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, SHEEP, BRICK)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (2, 5)),
#              Action(ORANGE MOVE_ROBBER ((-1, 1, 0), None, None)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (5, 3)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (5, 4)),
#              Action(RED MARITIME_TRADE (WOOD, WOOD, WOOD, None, SHEEP)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 4)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (2, 5)),
#              Action(ORANGE MOVE_ROBBER ((-2, 1, 1), <Color.RED: 'RED'>, WOOD)),
#              Action(ORANGE MARITIME_TRADE (ORE, ORE, ORE, None, WHEAT)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (1, 2)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (3, 2)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (2, 3)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, WHEAT)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (1, 6)),
#              Action(ORANGE MOVE_ROBBER ((1, 0, -1), None, None)),
#              Action(ORANGE BUILD_ROAD (45, 47)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (4, 1)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (2, 4)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (4, 3)),
#              Action(WHITE MOVE_ROBBER ((-1, 1, 0), <Color.ORANGE: 'ORANGE'>, ORE)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, SHEEP)),
#              Action(WHITE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, WHEAT, ORE)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, BRICK)),
#              Action(WHITE MARITIME_TRADE (BRICK, BRICK, BRICK, BRICK, SHEEP)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (3, 5)),
#              Action(ORANGE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, SHEEP)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (5, 4)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (3, 1)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 3)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (1, 1)),
#              Action(ORANGE MARITIME_TRADE (ORE, ORE, ORE, None, WOOD)),
#              Action(ORANGE MARITIME_TRADE (WOOD, WOOD, WOOD, None, ORE)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (2, 1)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (4, 2)),
#              Action(RED MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, BRICK)),
#              Action(RED BUILD_ROAD (34, 35)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (4, 6)),
#              Action(WHITE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, WHEAT, WOOD)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, WHEAT)),
#              Action(WHITE BUILD_SETTLEMENT 30),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (2, 6)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (3, 5)),
#              Action(BLUE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, BRICK)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (2, 4)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (2, 2)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (3, 4)),
#              Action(ORANGE MOVE_ROBBER ((0, -2, 2), <Color.WHITE: 'WHITE'>, WHEAT)),
#              Action(ORANGE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, ORE)),
#              Action(ORANGE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, ORE)),
#              Action(ORANGE MARITIME_TRADE (ORE, ORE, ORE, None, WOOD)),
#              Action(ORANGE BUILD_ROAD (13, 34)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (4, 3)),
#              Action(BLUE MOVE_ROBBER ((0, 0, 0), <Color.ORANGE: 'ORANGE'>, WHEAT)),
#              Action(BLUE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, None, BRICK)),
#              Action(BLUE BUILD_ROAD (51, 52)),
#              Action(BLUE BUILD_ROAD (32, 33)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (2, 3)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (1, 3)),
#              Action(WHITE MARITIME_TRADE (SHEEP, SHEEP, SHEEP, SHEEP, WOOD)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, WHEAT)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (2, 3)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (3, 3)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (3, 6)),
#              Action(RED END_TURN None),
#              Action(WHITE ROLL (5, 6)),
#              Action(WHITE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, WHEAT, ORE)),
#              Action(WHITE MARITIME_TRADE (WOOD, WOOD, None, None, WHEAT)),
#              Action(WHITE BUY_DEVELOPMENT_CARD DevelopmentCard.KNIGHT),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (2, 4)),
#              Action(ORANGE END_TURN None),
#              Action(BLUE ROLL (1, 5)),
#              Action(BLUE END_TURN None),
#              Action(RED ROLL (4, 3)),
#              Action(RED MOVE_ROBBER ((1, -2, 1), <Color.WHITE: 'WHITE'>, ORE)),
#              Action(RED MARITIME_TRADE (WHEAT, WHEAT, WHEAT, None, BRICK)),
#              Action(RED BUILD_SETTLEMENT 34),
#              Action(RED END_TURN None),
#              Action(WHITE PLAY_KNIGHT_CARD None),
#              Action(WHITE MOVE_ROBBER ((2, -1, -1), <Color.BLUE: 'BLUE'>, SHEEP)),
#              Action(WHITE ROLL (6, 3)),
#              Action(WHITE MARITIME_TRADE (WHEAT, WHEAT, WHEAT, WHEAT, ORE)),
#              Action(WHITE END_TURN None),
#              Action(ORANGE ROLL (4, 6)),
#              Action(ORANGE BUILD_CITY 12)],
#  'adjacent_tiles': defaultdict(<class 'list'>,
#                                {0: [Tile:3BRICK, Tile:4ORE, Tile:8ORE],
#                                 1: [Tile:3BRICK, Tile:5WOOD, Tile:8ORE],
#                                 2: [Tile:3BRICK, Tile:5WOOD, Tile:6WHEAT],
#                                 3: [Tile:3BRICK, Tile:6WHEAT, Tile:10SHEEP],
#                                 4: [Tile:3BRICK, Tile:10SHEEP, Tile:8SHEEP],
#                                 5: [Tile:3BRICK, Tile:8SHEEP, Tile:4ORE],
#                                 6: [Tile:5WOOD, Tile:8ORE, Tile:4SHEEP],
#                                 7: [Tile:5WOOD, Tile:12WHEAT, Tile:4SHEEP],
#                                 8: [Tile:5WOOD, Tile:12WHEAT, Tile:10WOOD],
#                                 9: [Tile:5WOOD, Tile:6WHEAT, Tile:10WOOD],
#                                 10: [Tile:6WHEAT, Tile:10WOOD, Tile:11SHEEP],
#                                 11: [Tile:6WHEAT, Tile:11SHEEP, Tile:2WOOD],
#                                 12: [Tile:6WHEAT, Tile:10SHEEP, Tile:2WOOD],
#                                 13: [Tile:10SHEEP, Tile:2WOOD, Tile:9WOOD],
#                                 14: [Tile:10SHEEP, Tile:9WOOD, Tile:6WHEAT],
#                                 15: [Tile:10SHEEP, Tile:8SHEEP, Tile:6WHEAT],
#                                 16: [Tile:8SHEEP, Tile:4ORE, Tile:Desert],
#                                 17: [Tile:8SHEEP, Tile:6WHEAT, Tile:5BRICK],
#                                 18: [Tile:8SHEEP, Tile:5BRICK, Tile:Desert],
#                                 19: [Tile:4ORE, Tile:9ORE, Tile:11BRICK],
#                                 20: [Tile:4ORE, Tile:8ORE, Tile:11BRICK],
#                                 21: [Tile:4ORE, Tile:Desert, Tile:9ORE],
#                                 22: [Tile:8ORE, Tile:11BRICK, Tile:3WHEAT],
#                                 23: [Tile:8ORE, Tile:3WHEAT, Tile:4SHEEP],
#                                 24: [Tile:12WHEAT, Tile:4SHEEP],
#                                 25: [Tile:12WHEAT],
#                                 26: [Tile:12WHEAT],
#                                 27: [Tile:12WHEAT, Tile:10WOOD],
#                                 28: [Tile:10WOOD],
#                                 29: [Tile:10WOOD, Tile:11SHEEP],
#                                 30: [Tile:11SHEEP],
#                                 31: [Tile:11SHEEP],
#                                 32: [Tile:11SHEEP, Tile:2WOOD],
#                                 33: [Tile:2WOOD],
#                                 34: [Tile:2WOOD, Tile:9WOOD],
#                                 35: [Tile:9WOOD],
#                                 36: [Tile:9WOOD],
#                                 37: [Tile:9WOOD, Tile:6WHEAT],
#                                 38: [Tile:6WHEAT],
#                                 39: [Tile:6WHEAT, Tile:5BRICK],
#                                 40: [Tile:5BRICK, Tile:Desert],
#                                 41: [Tile:5BRICK],
#                                 42: [Tile:5BRICK],
#                                 43: [Tile:Desert, Tile:9ORE],
#                                 44: [Tile:Desert],
#                                 45: [Tile:9ORE],
#                                 46: [Tile:9ORE, Tile:11BRICK],
#                                 47: [Tile:9ORE],
#                                 48: [Tile:11BRICK],
#                                 49: [Tile:11BRICK, Tile:3WHEAT],
#                                 50: [Tile:3WHEAT],
#                                 51: [Tile:3WHEAT],
#                                 52: [Tile:3WHEAT, Tile:4SHEEP],
#                                 53: [Tile:4SHEEP]}),
#  'bot_colors': [<Color.BLUE: 'BLUE'>,
#                 <Color.RED: 'RED'>,
#                 <Color.WHITE: 'WHITE'>,
#                 <Color.ORANGE: 'ORANGE'>],
#  'colors': (<Color.BLUE: 'BLUE'>,
#             <Color.RED: 'RED'>,
#             <Color.WHITE: 'WHITE'>,
#             <Color.ORANGE: 'ORANGE'>),
#  'current_color': <Color.ORANGE: 'ORANGE'>,
#  'current_playable_actions': [Action(ORANGE END_TURN None),
#                               Action(ORANGE BUY_DEVELOPMENT_CARD None),
#                               Action(ORANGE MARITIME_TRADE (BRICK, BRICK, BRICK, None, SHEEP)),
#                               Action(ORANGE MARITIME_TRADE (BRICK, BRICK, BRICK, None, ORE)),
#                               Action(ORANGE MARITIME_TRADE (BRICK, BRICK, BRICK, None, WOOD)),
#                               Action(ORANGE MARITIME_TRADE (BRICK, BRICK, BRICK, None, WHEAT))],
#  'current_prompt': <ActionPrompt.PLAY_TURN: 'PLAY_TURN'>,
#  'edges': [{'color': None,
#             'direction': 'WEST',
#             'id': (1, 2),
#             'tile_coordinate': (1, -1, 0)},
#            {'color': 'WHITE',
#             'direction': 'NORTHWEST',
#             'id': (2, 3),
#             'tile_coordinate': (0, -1, 1)},
#            {'color': 'ORANGE',
#             'direction': 'NORTHEAST',
#             'id': (3, 4),
#             'tile_coordinate': (-1, 0, 1)},
#            {'color': 'ORANGE',
#             'direction': 'EAST',
#             'id': (4, 5),
#             'tile_coordinate': (-1, 1, 0)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (0, 5),
#             'tile_coordinate': (0, 1, -1)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (0, 1),
#             'tile_coordinate': (1, 0, -1)},
#            {'color': 'WHITE',
#             'direction': 'WEST',
#             'id': (7, 8),
#             'tile_coordinate': (2, -2, 0)},
#            {'color': None,
#             'direction': 'NORTHWEST',
#             'id': (8, 9),
#             'tile_coordinate': (1, -2, 1)},
#            {'color': 'WHITE',
#             'direction': 'NORTHEAST',
#             'id': (2, 9),
#             'tile_coordinate': (0, -1, 1)},
#            {'color': 'WHITE',
#             'direction': 'SOUTHEAST',
#             'id': (1, 6),
#             'tile_coordinate': (1, 0, -1)},
#            {'color': 'WHITE',
#             'direction': 'SOUTHWEST',
#             'id': (6, 7),
#             'tile_coordinate': (2, -1, -1)},
#            {'color': 'WHITE',
#             'direction': 'WEST',
#             'id': (9, 10),
#             'tile_coordinate': (1, -2, 1)},
#            {'color': 'WHITE',
#             'direction': 'NORTHWEST',
#             'id': (10, 11),
#             'tile_coordinate': (0, -2, 2)},
#            {'color': 'WHITE',
#             'direction': 'NORTHEAST',
#             'id': (11, 12),
#             'tile_coordinate': (-1, -1, 2)},
#            {'color': 'ORANGE',
#             'direction': 'EAST',
#             'id': (3, 12),
#             'tile_coordinate': (-1, 0, 1)},
#            {'color': 'ORANGE',
#             'direction': 'NORTHWEST',
#             'id': (12, 13),
#             'tile_coordinate': (-1, -1, 2)},
#            {'color': 'ORANGE',
#             'direction': 'NORTHEAST',
#             'id': (13, 14),
#             'tile_coordinate': (-2, 0, 2)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (14, 15),
#             'tile_coordinate': (-2, 1, 1)},
#            {'color': 'ORANGE',
#             'direction': 'SOUTHEAST',
#             'id': (4, 15),
#             'tile_coordinate': (-1, 1, 0)},
#            {'color': None,
#             'direction': 'NORTHEAST',
#             'id': (15, 17),
#             'tile_coordinate': (-2, 1, 1)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (17, 18),
#             'tile_coordinate': (-2, 2, 0)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (16, 18),
#             'tile_coordinate': (-1, 2, -1)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (5, 16),
#             'tile_coordinate': (0, 1, -1)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (0, 20),
#             'tile_coordinate': (1, 0, -1)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (16, 21),
#             'tile_coordinate': (-1, 2, -1)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (19, 21),
#             'tile_coordinate': (0, 2, -2)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (19, 20),
#             'tile_coordinate': (1, 1, -2)},
#            {'color': 'WHITE',
#             'direction': 'WEST',
#             'id': (6, 23),
#             'tile_coordinate': (2, -1, -1)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (20, 22),
#             'tile_coordinate': (1, 1, -2)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (22, 23),
#             'tile_coordinate': (2, 0, -2)},
#            {'color': 'WHITE',
#             'direction': 'WEST',
#             'id': (25, 26),
#             'tile_coordinate': (3, -3, 0)},
#            {'color': None,
#             'direction': 'NORTHWEST',
#             'id': (26, 27),
#             'tile_coordinate': (2, -3, 1)},
#            {'color': 'WHITE',
#             'direction': 'NORTHEAST',
#             'id': (8, 27),
#             'tile_coordinate': (1, -2, 1)},
#            {'color': 'WHITE',
#             'direction': 'SOUTHEAST',
#             'id': (7, 24),
#             'tile_coordinate': (2, -1, -1)},
#            {'color': 'WHITE',
#             'direction': 'SOUTHWEST',
#             'id': (24, 25),
#             'tile_coordinate': (3, -2, -1)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (27, 28),
#             'tile_coordinate': (2, -3, 1)},
#            {'color': 'RED',
#             'direction': 'NORTHWEST',
#             'id': (28, 29),
#             'tile_coordinate': (1, -3, 2)},
#            {'color': 'WHITE',
#             'direction': 'NORTHEAST',
#             'id': (10, 29),
#             'tile_coordinate': (0, -2, 2)},
#            {'color': 'WHITE',
#             'direction': 'WEST',
#             'id': (29, 30),
#             'tile_coordinate': (1, -3, 2)},
#            {'color': None,
#             'direction': 'NORTHWEST',
#             'id': (30, 31),
#             'tile_coordinate': (0, -3, 3)},
#            {'color': 'BLUE',
#             'direction': 'NORTHEAST',
#             'id': (31, 32),
#             'tile_coordinate': (-1, -2, 3)},
#            {'color': 'BLUE',
#             'direction': 'EAST',
#             'id': (11, 32),
#             'tile_coordinate': (-1, -1, 2)},
#            {'color': 'BLUE',
#             'direction': 'NORTHWEST',
#             'id': (32, 33),
#             'tile_coordinate': (-1, -2, 3)},
#            {'color': None,
#             'direction': 'NORTHEAST',
#             'id': (33, 34),
#             'tile_coordinate': (-2, -1, 3)},
#            {'color': 'ORANGE',
#             'direction': 'EAST',
#             'id': (13, 34),
#             'tile_coordinate': (-2, 0, 2)},
#            {'color': 'RED',
#             'direction': 'NORTHWEST',
#             'id': (34, 35),
#             'tile_coordinate': (-2, -1, 3)},
#            {'color': 'RED',
#             'direction': 'NORTHEAST',
#             'id': (35, 36),
#             'tile_coordinate': (-3, 0, 3)},
#            {'color': 'RED',
#             'direction': 'EAST',
#             'id': (36, 37),
#             'tile_coordinate': (-3, 1, 2)},
#            {'color': 'RED',
#             'direction': 'SOUTHEAST',
#             'id': (14, 37),
#             'tile_coordinate': (-2, 1, 1)},
#            {'color': 'RED',
#             'direction': 'NORTHEAST',
#             'id': (37, 38),
#             'tile_coordinate': (-3, 1, 2)},
#            {'color': 'RED',
#             'direction': 'EAST',
#             'id': (38, 39),
#             'tile_coordinate': (-3, 2, 1)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (17, 39),
#             'tile_coordinate': (-2, 2, 0)},
#            {'color': None,
#             'direction': 'NORTHEAST',
#             'id': (39, 41),
#             'tile_coordinate': (-3, 2, 1)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (41, 42),
#             'tile_coordinate': (-3, 3, 0)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (40, 42),
#             'tile_coordinate': (-2, 3, -1)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (18, 40),
#             'tile_coordinate': (-1, 2, -1)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (40, 44),
#             'tile_coordinate': (-2, 3, -1)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (43, 44),
#             'tile_coordinate': (-1, 3, -2)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (21, 43),
#             'tile_coordinate': (0, 2, -2)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (19, 46),
#             'tile_coordinate': (1, 1, -2)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (43, 47),
#             'tile_coordinate': (-1, 3, -2)},
#            {'color': 'ORANGE',
#             'direction': 'SOUTHEAST',
#             'id': (45, 47),
#             'tile_coordinate': (0, 3, -3)},
#            {'color': 'ORANGE',
#             'direction': 'SOUTHWEST',
#             'id': (45, 46),
#             'tile_coordinate': (1, 2, -3)},
#            {'color': 'ORANGE',
#             'direction': 'WEST',
#             'id': (22, 49),
#             'tile_coordinate': (2, 0, -2)},
#            {'color': 'ORANGE',
#             'direction': 'SOUTHEAST',
#             'id': (46, 48),
#             'tile_coordinate': (1, 2, -3)},
#            {'color': 'ORANGE',
#             'direction': 'SOUTHWEST',
#             'id': (48, 49),
#             'tile_coordinate': (2, 1, -3)},
#            {'color': 'BLUE',
#             'direction': 'WEST',
#             'id': (51, 52),
#             'tile_coordinate': (3, -1, -2)},
#            {'color': 'BLUE',
#             'direction': 'NORTHWEST',
#             'id': (23, 52),
#             'tile_coordinate': (2, -1, -1)},
#            {'color': 'ORANGE',
#             'direction': 'SOUTHEAST',
#             'id': (49, 50),
#             'tile_coordinate': (2, 1, -3)},
#            {'color': 'ORANGE',
#             'direction': 'SOUTHWEST',
#             'id': (50, 51),
#             'tile_coordinate': (3, 0, -3)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (24, 53),
#             'tile_coordinate': (3, -2, -1)},
#            {'color': 'BLUE',
#             'direction': 'SOUTHWEST',
#             'id': (52, 53),
#             'tile_coordinate': (3, -1, -2)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (55, 56),
#             'tile_coordinate': (3, -3, 0)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (56, 57),
#             'tile_coordinate': (3, -3, 0)},
#            {'color': None,
#             'direction': 'NORTHEAST',
#             'id': (26, 57),
#             'tile_coordinate': (2, -3, 1)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (25, 54),
#             'tile_coordinate': (3, -2, -1)},
#            {'color': None,
#             'direction': 'NORTHEAST',
#             'id': (54, 55),
#             'tile_coordinate': (3, -3, 0)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (57, 58),
#             'tile_coordinate': (2, -3, 1)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (58, 59),
#             'tile_coordinate': (2, -3, 1)},
#            {'color': None,
#             'direction': 'NORTHEAST',
#             'id': (28, 59),
#             'tile_coordinate': (1, -3, 2)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (59, 60),
#             'tile_coordinate': (1, -3, 2)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (60, 61),
#             'tile_coordinate': (1, -3, 2)},
#            {'color': None,
#             'direction': 'NORTHEAST',
#             'id': (30, 61),
#             'tile_coordinate': (0, -3, 3)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (61, 62),
#             'tile_coordinate': (0, -3, 3)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (62, 63),
#             'tile_coordinate': (0, -3, 3)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (63, 64),
#             'tile_coordinate': (0, -3, 3)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (31, 64),
#             'tile_coordinate': (-1, -2, 3)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (64, 65),
#             'tile_coordinate': (-1, -2, 3)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (65, 66),
#             'tile_coordinate': (-1, -2, 3)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (33, 66),
#             'tile_coordinate': (-2, -1, 3)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (66, 67),
#             'tile_coordinate': (-2, -1, 3)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (67, 68),
#             'tile_coordinate': (-2, -1, 3)},
#            {'color': None,
#             'direction': 'EAST',
#             'id': (35, 68),
#             'tile_coordinate': (-3, 0, 3)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (68, 69),
#             'tile_coordinate': (-3, 0, 3)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (69, 70),
#             'tile_coordinate': (-3, 0, 3)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (70, 71),
#             'tile_coordinate': (-3, 0, 3)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (36, 71),
#             'tile_coordinate': (-3, 1, 2)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (71, 72),
#             'tile_coordinate': (-3, 1, 2)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (72, 73),
#             'tile_coordinate': (-3, 1, 2)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (38, 73),
#             'tile_coordinate': (-3, 2, 1)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (73, 74),
#             'tile_coordinate': (-3, 2, 1)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (74, 75),
#             'tile_coordinate': (-3, 2, 1)},
#            {'color': None,
#             'direction': 'SOUTHEAST',
#             'id': (41, 75),
#             'tile_coordinate': (-3, 3, 0)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (75, 77),
#             'tile_coordinate': (-3, 3, 0)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (77, 78),
#             'tile_coordinate': (-3, 3, 0)},
#            {'color': None,
#             'direction': 'NORTHWEST',
#             'id': (76, 78),
#             'tile_coordinate': (-3, 3, 0)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (42, 76),
#             'tile_coordinate': (-2, 3, -1)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (76, 80),
#             'tile_coordinate': (-2, 3, -1)},
#            {'color': None,
#             'direction': 'NORTHWEST',
#             'id': (79, 80),
#             'tile_coordinate': (-2, 3, -1)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (44, 79),
#             'tile_coordinate': (-1, 3, -2)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (79, 82),
#             'tile_coordinate': (-1, 3, -2)},
#            {'color': None,
#             'direction': 'NORTHWEST',
#             'id': (81, 82),
#             'tile_coordinate': (-1, 3, -2)},
#            {'color': None,
#             'direction': 'SOUTHWEST',
#             'id': (47, 81),
#             'tile_coordinate': (0, 3, -3)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (45, 84),
#             'tile_coordinate': (1, 2, -3)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (81, 85),
#             'tile_coordinate': (0, 3, -3)},
#            {'color': None,
#             'direction': 'NORTHWEST',
#             'id': (83, 85),
#             'tile_coordinate': (0, 3, -3)},
#            {'color': None,
#             'direction': 'NORTHEAST',
#             'id': (83, 84),
#             'tile_coordinate': (0, 3, -3)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (48, 87),
#             'tile_coordinate': (2, 1, -3)},
#            {'color': None,
#             'direction': 'NORTHWEST',
#             'id': (84, 86),
#             'tile_coordinate': (1, 2, -3)},
#            {'color': None,
#             'direction': 'NORTHEAST',
#             'id': (86, 87),
#             'tile_coordinate': (1, 2, -3)},
#            {'color': None,
#             'direction': 'WEST',
#             'id': (50, 89),
# ...
#                 'direction': 'SOUTH',
#                 'id': 65,
#                 'tile_coordinate': (-1, -2, 3)},
#            66: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHEAST',
#                 'id': 66,
#                 'tile_coordinate': (-2, -1, 3)},
#            67: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTH',
#                 'id': 67,
#                 'tile_coordinate': (-2, -1, 3)},
#            68: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHEAST',
#                 'id': 68,
#                 'tile_coordinate': (-3, 0, 3)},
#            69: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTH',
#                 'id': 69,
#                 'tile_coordinate': (-3, 0, 3)},
#            70: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 70,
#                 'tile_coordinate': (-3, 0, 3)},
#            71: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTH',
#                 'id': 71,
#                 'tile_coordinate': (-3, 1, 2)},
#            72: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 72,
#                 'tile_coordinate': (-3, 1, 2)},
#            73: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTH',
#                 'id': 73,
#                 'tile_coordinate': (-3, 2, 1)},
#            74: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 74,
#                 'tile_coordinate': (-3, 2, 1)},
#            75: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTH',
#                 'id': 75,
#                 'tile_coordinate': (-3, 3, 0)},
#            76: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 76,
#                 'tile_coordinate': (-2, 3, -1)},
#            77: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 77,
#                 'tile_coordinate': (-3, 3, 0)},
#            78: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 78,
#                 'tile_coordinate': (-3, 3, 0)},
#            79: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 79,
#                 'tile_coordinate': (-1, 3, -2)},
#            80: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 80,
#                 'tile_coordinate': (-2, 3, -1)},
#            81: {'building': None,
#                 'color': None,
#                 'direction': 'SOUTHWEST',
#                 'id': 81,
#                 'tile_coordinate': (0, 3, -3)},
#            82: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 82,
#                 'tile_coordinate': (-1, 3, -2)},
#            83: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 83,
#                 'tile_coordinate': (0, 3, -3)},
#            84: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 84,
#                 'tile_coordinate': (1, 2, -3)},
#            85: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 85,
#                 'tile_coordinate': (0, 3, -3)},
#            86: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 86,
#                 'tile_coordinate': (1, 2, -3)},
#            87: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 87,
#                 'tile_coordinate': (2, 1, -3)},
#            88: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 88,
#                 'tile_coordinate': (2, 1, -3)},
#            89: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHWEST',
#                 'id': 89,
#                 'tile_coordinate': (3, 0, -3)},
#            90: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 90,
#                 'tile_coordinate': (3, 0, -3)},
#            91: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHEAST',
#                 'id': 91,
#                 'tile_coordinate': (3, 0, -3)},
#            92: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 92,
#                 'tile_coordinate': (3, -1, -2)},
#            93: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHEAST',
#                 'id': 93,
#                 'tile_coordinate': (3, -1, -2)},
#            94: {'building': None,
#                 'color': None,
#                 'direction': 'NORTH',
#                 'id': 94,
#                 'tile_coordinate': (3, -2, -1)},
#            95: {'building': None,
#                 'color': None,
#                 'direction': 'NORTHEAST',
#                 'id': 95,
#                 'tile_coordinate': (3, -2, -1)}},
#  'player_state': {'P0_ACTUAL_VICTORY_POINTS': 2,
#                   'P0_BRICK_IN_HAND': 0,
#                   'P0_CITIES_AVAILABLE': 4,
#                   'P0_HAS_ARMY': False,
#                   'P0_HAS_PLAYED_DEVELOPMENT_CARD_IN_TURN': False,
#                   'P0_HAS_ROAD': False,
#                   'P0_HAS_ROLLED': False,
#                   'P0_KNIGHT_IN_HAND': 0,
#                   'P0_LONGEST_ROAD_LENGTH': 2,
#                   'P0_MONOPOLY_IN_HAND': 0,
#                   'P0_ORE_IN_HAND': 0,
#                   'P0_PLAYED_KNIGHT': 0,
#                   'P0_PLAYED_MONOPOLY': 0,
#                   'P0_PLAYED_ROAD_BUILDING': 0,
#                   'P0_PLAYED_VICTORY_POINT': 0,
#                   'P0_PLAYED_YEAR_OF_PLENTY': 0,
#                   'P0_ROADS_AVAILABLE': 9,
#                   'P0_ROAD_BUILDING_IN_HAND': 0,
#                   'P0_SETTLEMENTS_AVAILABLE': 3,
#                   'P0_SHEEP_IN_HAND': 1,
#                   'P0_VICTORY_POINTS': 2,
#                   'P0_VICTORY_POINT_IN_HAND': 1,
#                   'P0_WHEAT_IN_HAND': 1,
#                   'P0_WOOD_IN_HAND': 0,
#                   'P0_YEAR_OF_PLENTY_IN_HAND': 0,
#                   'P1_ACTUAL_VICTORY_POINTS': 3,
#                   'P1_BRICK_IN_HAND': 0,
#                   'P1_CITIES_AVAILABLE': 4,
#                   'P1_HAS_ARMY': False,
#                   'P1_HAS_PLAYED_DEVELOPMENT_CARD_IN_TURN': False,
#                   'P1_HAS_ROAD': False,
#                   'P1_HAS_ROLLED': False,
#                   'P1_KNIGHT_IN_HAND': 0,
#                   'P1_LONGEST_ROAD_LENGTH': 5,
#                   'P1_MONOPOLY_IN_HAND': 0,
#                   'P1_ORE_IN_HAND': 1,
#                   'P1_PLAYED_KNIGHT': 1,
#                   'P1_PLAYED_MONOPOLY': 0,
#                   'P1_PLAYED_ROAD_BUILDING': 0,
#                   'P1_PLAYED_VICTORY_POINT': 0,
#                   'P1_PLAYED_YEAR_OF_PLENTY': 0,
#                   'P1_ROADS_AVAILABLE': 8,
#                   'P1_ROAD_BUILDING_IN_HAND': 0,
#                   'P1_SETTLEMENTS_AVAILABLE': 2,
#                   'P1_SHEEP_IN_HAND': 0,
#                   'P1_VICTORY_POINTS': 3,
#                   'P1_VICTORY_POINT_IN_HAND': 1,
#                   'P1_WHEAT_IN_HAND': 0,
#                   'P1_WOOD_IN_HAND': 4,
#                   'P1_YEAR_OF_PLENTY_IN_HAND': 0,
#                   'P2_ACTUAL_VICTORY_POINTS': 7,
#                   'P2_BRICK_IN_HAND': 0,
#                   'P2_CITIES_AVAILABLE': 4,
#                   'P2_HAS_ARMY': True,
#                   'P2_HAS_PLAYED_DEVELOPMENT_CARD_IN_TURN': False,
#                   'P2_HAS_ROAD': False,
#                   'P2_HAS_ROLLED': False,
#                   'P2_KNIGHT_IN_HAND': 0,
#                   'P2_LONGEST_ROAD_LENGTH': 5,
#                   'P2_MONOPOLY_IN_HAND': 0,
#                   'P2_ORE_IN_HAND': 2,
#                   'P2_PLAYED_KNIGHT': 3,
#                   'P2_PLAYED_MONOPOLY': 0,
#                   'P2_PLAYED_ROAD_BUILDING': 0,
#                   'P2_PLAYED_VICTORY_POINT': 0,
#                   'P2_PLAYED_YEAR_OF_PLENTY': 0,
#                   'P2_ROADS_AVAILABLE': 0,
#                   'P2_ROAD_BUILDING_IN_HAND': 2,
#                   'P2_SETTLEMENTS_AVAILABLE': 0,
#                   'P2_SHEEP_IN_HAND': 2,
#                   'P2_VICTORY_POINTS': 7,
#                   'P2_VICTORY_POINT_IN_HAND': 0,
#                   'P2_WHEAT_IN_HAND': 0,
#                   'P2_WOOD_IN_HAND': 2,
#                   'P2_YEAR_OF_PLENTY_IN_HAND': 0,
#                   'P3_ACTUAL_VICTORY_POINTS': 10,
#                   'P3_BRICK_IN_HAND': 3,
#                   'P3_CITIES_AVAILABLE': 2,
#                   'P3_HAS_ARMY': False,
#                   'P3_HAS_PLAYED_DEVELOPMENT_CARD_IN_TURN': False,
#                   'P3_HAS_ROAD': True,
#                   'P3_HAS_ROLLED': True,
#                   'P3_KNIGHT_IN_HAND': 0,
#                   'P3_LONGEST_ROAD_LENGTH': 6,
#                   'P3_MONOPOLY_IN_HAND': 0,
#                   'P3_ORE_IN_HAND': 1,
#                   'P3_PLAYED_KNIGHT': 4,
#                   'P3_PLAYED_MONOPOLY': 2,
#                   'P3_PLAYED_ROAD_BUILDING': 0,
#                   'P3_PLAYED_VICTORY_POINT': 0,
#                   'P3_PLAYED_YEAR_OF_PLENTY': 0,
#                   'P3_ROADS_AVAILABLE': 1,
#                   'P3_ROAD_BUILDING_IN_HAND': 0,
#                   'P3_SETTLEMENTS_AVAILABLE': 3,
#                   'P3_SHEEP_IN_HAND': 2,
#                   'P3_VICTORY_POINTS': 10,
#                   'P3_VICTORY_POINT_IN_HAND': 0,
#                   'P3_WHEAT_IN_HAND': 1,
#                   'P3_WOOD_IN_HAND': 0,
#                   'P3_YEAR_OF_PLENTY_IN_HAND': 0},
#  'robber_coordinate': (2, -1, -1),
#  'tiles': [{'coordinate': (0, 0, 0),
#             'tile': {'id': 0,
#                      'number': 3,
#                      'resource': 'BRICK',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (1, -1, 0),
#             'tile': {'id': 1,
#                      'number': 5,
#                      'resource': 'WOOD',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (0, -1, 1),
#             'tile': {'id': 2,
#                      'number': 6,
#                      'resource': 'WHEAT',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-1, 0, 1),
#             'tile': {'id': 3,
#                      'number': 10,
#                      'resource': 'SHEEP',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-1, 1, 0),
#             'tile': {'id': 4,
#                      'number': 8,
#                      'resource': 'SHEEP',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (0, 1, -1),
#             'tile': {'id': 5,
#                      'number': 4,
#                      'resource': 'ORE',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (1, 0, -1),
#             'tile': {'id': 6,
#                      'number': 8,
#                      'resource': 'ORE',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (2, -2, 0),
#             'tile': {'id': 7,
#                      'number': 12,
#                      'resource': 'WHEAT',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (1, -2, 1),
#             'tile': {'id': 8,
#                      'number': 10,
#                      'resource': 'WOOD',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (0, -2, 2),
#             'tile': {'id': 9,
#                      'number': 11,
#                      'resource': 'SHEEP',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-1, -1, 2),
#             'tile': {'id': 10,
#                      'number': 2,
#                      'resource': 'WOOD',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-2, 0, 2),
#             'tile': {'id': 11,
#                      'number': 9,
#                      'resource': 'WOOD',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-2, 1, 1),
#             'tile': {'id': 12,
#                      'number': 6,
#                      'resource': 'WHEAT',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-2, 2, 0),
#             'tile': {'id': 13,
#                      'number': 5,
#                      'resource': 'BRICK',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (-1, 2, -1), 'tile': {'id': 14, 'type': 'DESERT'}},
#            {'coordinate': (0, 2, -2),
#             'tile': {'id': 15,
#                      'number': 9,
#                      'resource': 'ORE',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (1, 1, -2),
#             'tile': {'id': 16,
#                      'number': 11,
#                      'resource': 'BRICK',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (2, 0, -2),
#             'tile': {'id': 17,
#                      'number': 3,
#                      'resource': 'WHEAT',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (2, -1, -1),
#             'tile': {'id': 18,
#                      'number': 4,
#                      'resource': 'SHEEP',
#                      'type': 'RESOURCE_TILE'}},
#            {'coordinate': (3, -3, 0),
#             'tile': {'direction': 'WEST',
#                      'id': 0,
#                      'resource': 'WOOD',
#                      'type': 'PORT'}},
#            {'coordinate': (2, -3, 1), 'tile': {'type': 'WATER'}},
#            {'coordinate': (1, -3, 2),
#             'tile': {'direction': 'NORTHWEST',
#                      'id': 1,
#                      'resource': None,
#                      'type': 'PORT'}},
#            {'coordinate': (0, -3, 3), 'tile': {'type': 'WATER'}},
#            {'coordinate': (-1, -2, 3),
#             'tile': {'direction': 'NORTHWEST',
#                      'id': 2,
#                      'resource': None,
#                      'type': 'PORT'}},
#            {'coordinate': (-2, -1, 3), 'tile': {'type': 'WATER'}},
#            {'coordinate': (-3, 0, 3),
#             'tile': {'direction': 'NORTHEAST',
#                      'id': 3,
#                      'resource': 'BRICK',
#                      'type': 'PORT'}},
#            {'coordinate': (-3, 1, 2), 'tile': {'type': 'WATER'}},
#            {'coordinate': (-3, 2, 1),
#             'tile': {'direction': 'EAST',
#                      'id': 4,
#                      'resource': 'ORE',
#                      'type': 'PORT'}},
#            {'coordinate': (-3, 3, 0), 'tile': {'type': 'WATER'}},
#            {'coordinate': (-2, 3, -1),
#             'tile': {'direction': 'EAST',
#                      'id': 5,
#                      'resource': 'WHEAT',
#                      'type': 'PORT'}},
#            {'coordinate': (-1, 3, -2), 'tile': {'type': 'WATER'}},
#            {'coordinate': (0, 3, -3),
#             'tile': {'direction': 'SOUTHEAST',
#                      'id': 6,
#                      'resource': 'SHEEP',
#                      'type': 'PORT'}},
#            {'coordinate': (1, 2, -3), 'tile': {'type': 'WATER'}},
#            {'coordinate': (2, 1, -3),
#             'tile': {'direction': 'SOUTHWEST',
#                      'id': 7,
#                      'resource': None,
#                      'type': 'PORT'}},
#            {'coordinate': (3, 0, -3), 'tile': {'type': 'WATER'}},
#            {'coordinate': (3, -1, -2),
#             'tile': {'direction': 'SOUTHWEST',
#                      'id': 8,
#                      'resource': None,
#                      'type': 'PORT'}},
#            {'coordinate': (3, -2, -1), 'tile': {'type': 'WATER'}}],
#  'winning_color': <Color.ORANGE: 'ORANGE'>}
